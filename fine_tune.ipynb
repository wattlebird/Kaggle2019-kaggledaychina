# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from fastai.metrics import error_rate, AUROC

# %%
np.random.seed(233)
data = ImageDataBunch.from_folder(path='/home/ike/Data/kaggledayschina/kaggledays-china/train3c', train='.', valid_pct=0.2, ds_tfms=get_transforms(flip_vert=True, max_rotate=45), size=224, bs=128).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=[error_rate, AUROC()])

# %%
learn.load("/home/ike/Data/kaggledayschina/kaggledays-china/resnet34-82-save")
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (4020 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# nonstar,nonstar,nonstar,nonstar,nonstar
# Path: /home/ike/Data/kaggledayschina/kaggledays-china/train3c;
#
# Valid: LabelList (1004 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# nonstar,nonstar,nonstar,nonstar,nonstar
# Path: /home/ike/Data/kaggledayschina/kaggledays-china/train3c;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.miniconda3/envs/py36/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#
# ~/.miniconda3/envs/py36/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#
# ~/.miniconda3/envs/py36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
# ...
